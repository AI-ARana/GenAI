# %%
from mpl_toolkits import mplot3d

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\Anurag Rana\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv('D:\FirstUniv\DataSet\sal_bm.csv')
df
# Out:
#            Unnamed: 0      Salary       latd       longt
# 0         El Paso, TX   65.497368  31.777576 -106.442456
# 1    Indianapolis, IN   75.298944  39.768403  -86.158068
# 2       Nashville, TN   76.190975  36.162664  -86.781602
# 3     San Antonio, TX   76.352052  29.424122  -98.493628
# 4    Jacksonville, FL   79.146182  30.332184  -81.655651
# 5        Columbus, OH   81.004893  39.961176  -82.998794
# 6         Houston, TX   81.730901  29.760427  -95.369803
# 7    Philadelphia, PA   82.700565  39.952584  -75.165222
# 8      Fort Worth, TX   82.705179  32.755488  -97.330766
# 9         Detroit, MI   82.763078  42.331427  -83.045754
# 10        Phoenix, AZ   83.060319  33.448377 -112.074037
# 11         Dallas, TX   85.834199  32.776664  -96.796988
# 12      Charlotte, NC   86.095056  35.227087  -80.843127
# 13       Portland, OR   88.774615  45.523062 -122.676482
# 14      San Diego, CA   90.103168  32.715738 -117.161084
# ...

# %%
df=pd.read_csv('D:\vinay\table\test.csv')
df.info()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 df=pd.read_csv('D:\vinay\table\test.csv')
#       2 df.info()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df=pd.read_csv("D:/vinay/table/test.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Surfactant           6 non-null      int64
#  1   cmca/cmcb/cmcc (mM)  6 non-null      object
#  2   ?                    6 non-null      float64
#  3   ?cmc (mN/m)          6 non-null      float64
#  4   ?max (?mol/m2)       6 non-null      float64
#  5   Amin (nm2)           6 non-null      float64
#  6   C20 (10-4)           6 non-null      float64
#  7   ?cmc (mN/m).1        6 non-null      float64
#  8   ?G°mic (cmc/C20)     6 non-null      float64
#  9   kJ/mol               6 non-null      float64
#  10  ?G°ads(kJ/mol)       6 non-null      float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 656.0+ bytes

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
DataAll1D = np.loadtxt("D:/vinay/table/t2.csv", delimiter=",")

# create 2d x,y grid (both X and Y will be 2d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 DataAll1D = np.loadtxt("D:/vinay/table/t2.csv", delimiter=",")
#
# File ~\anaconda3\lib\site-packages\numpy\lib\npyio.py:1148, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1143 # read data in chunks and fill it into an array via resize
#    1144 # over-allocating and shrinking the array later may be faster but is
#    1145 # probably not relevant compared to the cost of actually reading and
#    1146 # converting the data
#    1147 X = None
# -> 1148 for x in read_data(_loadtxt_chunksize):
#    1149     if X is None:
#    1150         X = np.array(x, dtype)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\npyio.py:999, in loadtxt.<locals>.read_data(chunk_size)
# ...

# %%
X, Y = np.meshgrid(df[:,0], df[:,1])

# repeat Z to make it a 2d grid
Z = np.tile(df[:,2], (len(df[:,2]), 1))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(X, Y, Z, cmap='ocean')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 0)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Input In [62], in <cell line: 1>()
# ----> 1 X, Y = np.meshgrid(df[:,0], df[:,1])
#       3 # repeat Z to make it a 2d grid
#       4 Z = np.tile(df[:,2], (len(df[:,2]), 1))
#
# ...

# %%
df = pd.DataFrame(df, columns=["Surfactant", "Size (Dh ; nm)", "Diffusion Coefficient (107D/cm2s-1)","Zeta Potential (mV)"])
 
# plot the dataframe
df.plot(x="Surfactant", y=["Size (Dh ; nm)", "Diffusion Coefficient (107D/cm2s-1)","Zeta Potential (mV)"], kind="line", figsize=(9, 8))
 
# print bar graph
plt.show()

# %%
heat_map=sns.heatmap(df1,cmap="gist_rainbow")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
 
 
# reading the database
data = pd.read_csv("tips.csv")
 
# using only data attribute
sns.lineplot(data=data.drop(['total_bill'], axis=1))
plt.show()
# Out:
# C:\Users\Anurag Rana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [25], in <cell line: 2>()
#       1 # using only data attribute
# ----> 2 sns.lineplot(df1, axis=1)
#       3 plt.show()
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
# ...
