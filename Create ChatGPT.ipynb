# %%
import openai

# %%
openai.api_key="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"

# %%
models=openai.Model.list()

# %%
print(models.data[0].id)
# Out:
# babbage

# %%
completion=openai.Completion.create(model='ada',prompt="Hello Firstuniv")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# C:\conda_tmp\ipykernel_35268\2724549420.py in <module>
# ----> 1 completion=openai.Completion.create(model='ada',prompt="Hello Firstuniv")
#
# F:\Anaconda\lib\site-packages\openai\api_resources\completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# F:\Anaconda\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     151         )
#     152
# --> 153         response, _, api_key = requestor.request(
#     154             "post",
#     155             url,
#
# ...

# %%
print(completion.choices[0].text)
# Out:
# ention Instagram Post”, 4th April 2018
#
# @MindsetHQ

# %%
openai.api_type="azure"
openai.api_key="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"
openai.api_base="https://example-endpoint.openai.azure.com"
openai.api_version="2023-03-26-preview"
completion=openai.Completion.create(deployment_id="deployment-name",prompt="Hello FirstUniv")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# F:\Anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# F:\Anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      71
# ---> 72     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73         af, socktype, proto, canonname, sa = res
#
# F:\Anaconda\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# F:\Anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# F:\Anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      71
# ---> 72     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73         af, socktype, proto, canonname, sa = res
#
# F:\Anaconda\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# ...

# %%
print(completion.choices[0].text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\conda_tmp\ipykernel_35268\1836596482.py in <module>
# ----> 1 print(completion.choices[0].text)
#
# NameError: name 'completion' is not defined

# %%
while True:
    model_engine="texr-divici-003"
    
    prompt=input('Enter new prompt: ')
    
    if 'exit' in prompt or 'quit' in prompt:
        break
    
    completion=openai.Completion.create(engine=model_engine, prompt=prompt,max_tokens=1024,n=1,stop=None,temperature=0.5)
    response=completion.choices[0].text
    print(response)
# Out:
# Enter new prompt: Fisrtuniv
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# F:\Anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# F:\Anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      71
# ---> 72     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73         af, socktype, proto, canonname, sa = res
#
# F:\Anaconda\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# ...
