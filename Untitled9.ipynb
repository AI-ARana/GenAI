# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as sts


pd.set_option('display.max_rows',None)

# %%
mart = pd.read_excel(r"D:\Data_h\BENZI Toxicity Results.xlsx")

mart.head(10)
# Out:
#                 Unnamed: 0  BENZI-0125  BENZI-0279  BENZI-0415  BENZI-0437  \
# 0            hERG Blockers         0.1         0.1         0.1         0.1
# 1                     H-HT         0.5         0.5         0.9         0.5
# 2                     DILI         1.0         1.0         1.0         1.0
# 3            AMES Toxicity         1.0         0.9         1.0         1.0
# 4  Rat Oral Acute Toxicity         0.1         0.1         0.1         0.1
# 5                   FDAMDD         0.1         0.9         0.9         0.3
# 6       Skin Sensitization         0.3         0.5         0.3         0.7
# 7          Carcinogenicity         1.0         0.7         0.9         0.9
# 8            Eye Corrosion         0.1         0.1         0.1         0.1
# 9           Eye Irritation         0.3         0.1         0.1         0.5
#
#    BENZI-0660  BENZI-1110
# 0         0.1         0.1
# 1         0.9         0.7
# 2         1.0         1.0
# 3         0.9         0.9
# ...

# %%
from matplotlib import font_manager
sns.set()

sns.set(style='ticks')

hm=sns.kdeplot(data = mart,levels=100,fill=True ,cbar=True,thresh=0.1)

plt.xticks(fontname="Times New Roman",fontsize=12,rotation=0,weight='bold')   
plt.yticks(fontname="Times New Roman",fontsize=12,rotation=0,weight='bold')

plt.xlabel('Compound', fontsize=12, fontname="Times New Roman", weight='bold')
plt.ylabel('Properties', fontsize=12,fontname="Times New Roman",weight='bold')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10752\2878427028.py in <module>
#       4 sns.set(style='ticks')
#       5
# ----> 6 hm=sns.kdeplot(data = mart,levels=100,cmap='rainbow',fill=True ,cbar=True,thresh=0.1)
#       7
#       8 plt.xticks(fontname="Times New Roman",fontsize=12,rotation=0,weight='bold')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
hm=hm.get_figure()
hm.savefig('f:\KDE-Plot of Binding affinity and Ligand efficiency.png', bbox_inches='tight', dpi=300)

# %%
sns.jointplot(data=mart)

# %%
sns.pairplot(data=mart)

# %%
g = sns.PairGrid(mart,corner=True)
g.map_lower(sns.kdeplot, hue=None, levels=5, color=".2")
g.map_lower(sns.scatterplot, marker="+")
g.map_diag(sns.histplot, element="step", linewidth=0, kde=True)
g.add_legend(frameon=True)
g.legend.set_bbox_to_anchor((.61, .6))

# %%
sns.kdeplot(,color='r', shade=True, Label='Iris_Setosa',
            cmap="Reds", shade_lowest=False)
# Out:
# C:\Users\Anurag Rana\anaconda3\lib\site-packages\seaborn\distributions.py:1718: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0.05`, but please update your code.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:>

# %%
g = sns.PairGrid(mart,hue="smoker",
                  palette='RdBu_r')
g.map(plt.scatter, alpha=0.8)
g.add_legend();
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'smoker'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
