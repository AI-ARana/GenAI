# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as sts


pd.set_option('display.max_rows',None)

# %%
mart = pd.read_excel(r"D:\Data_h\BENZI-Oral Acute Toxicity.xlsx")

mart.head(10)
# Out:
#    BENZI-0660  Reference Ligand
# 0         0.1               0.5
# 1         0.9               0.7
# 2         1.0               1.0
# 3         0.9               0.7
# 4         0.1               0.5
# 5         0.9               0.1
# 6         0.5               1.0
# 7         0.9               0.5
# 8         0.1               0.1
# 9         0.1               0.1

# %%
sns.set_theme(context='notebook', style='ticks', palette='RdYlBu', font='Times New Roman', font_scale=1.5, color_codes=True, rc=None)
sns.kdeplot(data = mart,x='BENZI-0660',y='Reference Ligand', levels=100,cmap="rainbow" ,cbar=True,thresh=0.10, shade=True)
# Out:
# <AxesSubplot:xlabel='BENZI-0660', ylabel='Reference Ligand'>
